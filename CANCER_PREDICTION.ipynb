# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
cancer = pd.read_csv('/content/cancer.csv')

# %%
cancer.head()
# Out:
#    Gender  Age  Smoking  Fatigue  Allergy  Cancer
# 0       1   85        1        0        1       0
# 1       1   93        0        0        0       0
# 2       1   72        0        1        0       0
# 3       0   58        0        0        1       0
# 4       1   95        1        0        1       1

# %%
cancer.shape
# Out:
# (10000, 6)

# %%
cancer.isna().sum()
# Out:
# Gender     0
# Age        0
# Smoking    0
# Fatigue    0
# Allergy    0
# Cancer     0
# dtype: int64

# %%
cancer['Cancer'].value_counts()
# Out:
# Cancer
# 0    9036
# 1     964
# Name: count, dtype: int64

# %%
cancer.groupby('Cancer').mean()
# Out:
#           Gender        Age   Smoking   Fatigue   Allergy
# Cancer
# 0       0.499889  59.450863  0.500885  0.502103  0.499225
# 1       0.475104  58.076763  0.493776  0.498963  0.506224

# %%
x=cancer.iloc[:,:-1]
y=cancer.iloc[:,-1]

# %%
x
# Out:
#       Gender  Age  Smoking  Fatigue  Allergy
# 0          1   85        1        0        1
# 1          1   93        0        0        0
# 2          1   72        0        1        0
# 3          0   58        0        0        1
# 4          1   95        1        0        1
# ...      ...  ...      ...      ...      ...
# 9995       1   89        1        0        1
# 9996       0   23        1        1        0
# 9997       1   99        0        0        1
# 9998       0   26        0        1        1
# 9999       1   52        1        1        0
#
# [10000 rows x 5 columns]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: Cancer, Length: 10000, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state=2)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (10000, 5) (8000, 5) (2000, 5)

# %%
Classifier = svm.SVC(kernel='linear')
Classifier.fit(x_train, y_train)                               #training the support vector Machine Classifier
# Out:
# SVC(kernel='linear')

# %%
# accuracy score
x_train_prediction = Classifier.predict(x_train)
train_accuracy = accuracy_score(x_train_prediction, y_train)

# %%
print('Accuracy score of  training data : ', train_accuracy)
# Out:
# Accuracy score of  training data :  0.902625

# %%
x_test_prediction = Classifier.predict(x_test)
test_accuracy = accuracy_score(x_test_prediction, y_test)

# %%
print('Accuracy score of  test data : ', test_accuracy)
# Out:
# Accuracy score of  test data :  0.9075

# %%
import pickle

# %%
pickle.dump(Classifier,open("Cancer.pkl","wb"))

# %%
pm=pickle.load(open("Cancer.pkl","rb"))

# %%
i_d = (1,95,1,0,1)

i_d_array= np.asarray(i_d)                    # changing the input_data to numpy array

reshaped = i_d_array.reshape(1,-1)          # reshape the array as we are predicting for one instance

prediction = Classifier.predict(reshaped)
print(prediction)

if (prediction[0] == 0):
  print('The person not in cancer')
else:
  print('The person is cancer')
# Out:
# [0]
# The person not in cancer
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
